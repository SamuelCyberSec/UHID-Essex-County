# %% [markdown]
# # Mount Drive

# %%
"""
UHID Essex County - Setup & Data Verification
Author: Samuel Grant Quansah
Date: November 2025
"""

# ============================================
# STEP 1 — Mount Google Drive
# ============================================

from google.colab import drive
drive.mount('/content/drive')

# ============================================
# STEP 2 — Clone GitHub Repository
# ============================================

# Remove existing folder if running notebook multiple times
# !rm -rf UHID-Essex-County

# !git clone https://github.com/SamuelCyberSec/UHID-Essex-County.git
# %cd UHID-Essex-County

# ============================================
# STEP 3 — Set Data Path
# ============================================

import os

DRIVE_DATA = '/content/drive/MyDrive/SharedFilesUHIDTeam'
print("Data directory set to:", DRIVE_DATA)

# ============================================
# STEP 4 — Folder Verification Check
# ============================================

folders = [
    '01_Satellite_LST',
    '02_Land_Cover',
    '03_Socioeconomic',
    '04_Local_Essex',
    '05_Building_Data',
    '06_RoadNetwork_and_Traffic'
]

print("\n=== DATA VERIFICATION ===")
for folder in folders:
    path = os.path.join(DRIVE_DATA, folder)
    exists = "✓ FOUND" if os.path.exists(path) else "✗ MISSING"
    print(f"{exists}  ->  {folder}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Cloning into 'UHID-Essex-County'...
# remote: Enumerating objects: 94, done.
# remote: Counting objects: 100% (94/94), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 94 (delta 30), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (94/94), 31.72 KiB | 927.00 KiB/s, done.
# Resolving deltas: 100% (30/30), done.
# /content/UHID-Essex-County/UHID-Essex-County/UHID-Essex-County/UHID-Essex-County/UHID-Essex-County
# Data directory set to: /content/drive/MyDrive/SharedFilesUHIDTeam
#
# === DATA VERIFICATION ===
# ✓ FOUND  ->  01_Satellite_LST
# ✓ FOUND  ->  02_Land_Cover
# ✓ FOUND  ->  03_Socioeconomic
# ✓ FOUND  ->  04_Local_Essex
# ✓ FOUND  ->  05_Building_Data
# ✗ MISSING  ->  06_RoadNetwork_and_Traffic
